# %%
print('hi')
# Out:
# hi

# %% [markdown]
# # hi

# %%
import pandas as pd

# %%
from datasets import load_dataset
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
import pandas as pd
from datasets import load_dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
# Out:
# Using the latest cached version of the dataset since lukebarousse/data_jobs couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at C:\Users\Rajashekar\.cache\huggingface\datasets\lukebarousse___data_jobs\default\0.0.0\1d815e9ce232eb27db11939c44eb048fe6d2e9ab (last modified on Fri Nov 29 20:36:21 2024).

# %%
df.iloc[0:10]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                                      Data Engineer
# 8      Business Analyst           Technology & Operations Business Analyst
# 9        Data Scientist                                  Data Scientist II
#
#                    job_location             job_via         job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby                 Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México                 Full-time
# 2               Berlin, Germany        via LinkedIn                 Full-time
# 3               San Antonio, TX   via Diversity.com                 Full-time
# 4                Washington, DC  via Clearance Jobs                 Full-time
# 5                      Anywhere    via ZipRecruiter  Contractor and Temp work
# 6                  Dearborn, MI        via LinkedIn                 Full-time
# 7                      Anywhere        via LinkedIn                 Full-time
# 8           Copenhagen, Denmark     via Trabajo.org                 Full-time
# 9                      Anywhere    via ZipRecruiter                 Full-time
#
#    job_work_from_home          search_location     job_posted_date  \
# 0               False     Texas, United States 2023-06-16 13:44:15
# 1               False                   Mexico 2023-01-14 13:18:07
# 2               False                  Germany 2023-10-10 13:14:55
# 3               False     Texas, United States 2023-07-04 13:01:41
# 4               False                    Sudan 2023-08-07 14:29:36
# 5                True                  Georgia 2023-11-07 14:01:59
# 6               False   Florida, United States 2023-03-27 13:18:18
# 7                True                  Romania 2023-12-07 13:40:49
# 8               False                  Denmark 2023-06-05 13:44:34
# 9                True  New York, United States 2023-04-23 13:02:57
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
# 5                  False                 False  United States        None
# 6                  False                 False  United States        None
# 7                  False                 False        Romania        None
# 8                  False                 False        Denmark        None
# 9                  False                 False  United States        None
#
#    salary_year_avg  salary_hour_avg                   company_name  \
# 0              NaN              NaN           Boehringer Ingelheim
# 1              NaN              NaN     Hewlett Packard Enterprise
# 2              NaN              NaN       ALPHA Augmented Services
# 3              NaN              NaN   Southwest Research Institute
# 4              NaN              NaN                Kristina Daniel
# 5              NaN              NaN                smart folks inc
# 6              NaN              NaN  Miracle Software Systems, Inc
# 7              NaN              NaN                          Zitec
# 8              NaN              NaN                         Hempel
# 9              NaN              NaN     Radwell International, LLC
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
# 5                           ['python', 'sql', 'gcp']
# 6  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 7  ['sql', 'nosql', 'gcp', 'azure', 'aws', 'bigqu...
# 8                ['excel', 'powerpoint', 'power bi']
# 9  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# 5  {'cloud': ['gcp'], 'programming': ['python', '...
# 6  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 7  {'cloud': ['gcp', 'azure', 'aws', 'bigquery', ...
# 8  {'analyst_tools': ['excel', 'powerpoint', 'pow...
# 9  {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
df.loc[:, 'salary_rate':'salary_hour_avg'].dropna(subset= 'salary_rate')
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 28            year         109500.0              NaN
# 43            hour              NaN             97.5
# 51            hour              NaN             72.5
# 77            year         140000.0              NaN
# 92            year         120000.0              NaN
# ...            ...              ...              ...
# 785624        year         139216.0              NaN
# 785641        year         150000.0              NaN
# 785648        year         221875.0              NaN
# 785682        year         157500.0              NaN
# 785692        year         157500.0              NaN
#
# [33067 rows x 3 columns]

# %%
medain_salary_hour = df['salary_hour_avg'].median()

# %%
median_salary_year = df['salary_year_avg'].median()

# %% [markdown]
# # Pandas: data cleaning

# %%
df.loc[:10,'salary_year_avg':'salary_hour_avg']
# Out:
#     salary_year_avg  salary_hour_avg
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# 5               NaN              NaN
# 6               NaN              NaN
# 7               NaN              NaN
# 8               NaN              NaN
# 9               NaN              NaN
# 10              NaN              NaN

# %%
median_salary_year = df['salary_year_avg'].median()

# %%
medain_salary_hour =df['salary_hour_avg'].median()

# %%
df_filled = df
df_filled['salary_year_avg']=df_filled['salary_year_avg'].fillna(median_salary_year)
df_filled['salary_hour_avg']=df_filled['salary_hour_avg'].fillna(medain_salary_hour)

# %%
df_filled.loc[:10,'salary_year_avg':'salary_hour_avg']
# Out:
#     salary_year_avg  salary_hour_avg
# 0          115000.0            45.98
# 1          115000.0            45.98
# 2          115000.0            45.98
# 3          115000.0            45.98
# 4          115000.0            45.98
# 5          115000.0            45.98
# 6          115000.0            45.98
# 7          115000.0            45.98
# 8          115000.0            45.98
# 9          115000.0            45.98
# 10         115000.0            45.98

# %%
df_unique = df_filled

# %%
df_unique.drop_duplicates()
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None         115000.0            45.98
# 1              Mexico        None         115000.0            45.98
# 2             Germany        None         115000.0            45.98
# 3       United States        None         115000.0            45.98
# 4               Sudan        None         115000.0            45.98
# ...               ...         ...              ...              ...
# 785736      Singapore        None         115000.0            45.98
# 785737        Germany        None         115000.0            45.98
# 785738       Malaysia        None         115000.0            45.98
# 785739          Sudan        None         115000.0            45.98
# 785740          India        None         115000.0            45.98
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785640 rows x 17 columns]

# %%
df_unique=df_filled

df_unique=df_filled.drop_duplicates()

print('length of the original df:', len(df_filled))
print('length of drop duplicates df:', len(df_unique))
print('rows dropped:', len(df_filled)-len(df_unique))
# Out:
# length of the original df: 785741
# length of drop duplicates df: 785640
# rows dropped: 101

# %%
df_unique=df_filled.drop_duplicates(subset=['job_title','company_name'])
print('length of the original df:', len(df_filled))
print('length of drop duplicates df:', len(df_unique))
print('rows dropped:', len(df_filled)-len(df_unique))
# Out:
# length of the original df: 785741
# length of drop duplicates df: 508042
# rows dropped: 277699

# %% [markdown]
# # Pandas: data management

# %%
df.sample(10)
# Out:
#          job_title_short                                          job_title  \
# 548123      Data Analyst           Data Analyst / DS (Any Fresher Trainee)-
# 139193      Data Analyst                                       Data Analyst
# 416566  Business Analyst                           Billing Analyst, Finance
# 363968     Data Engineer                               Data Devops Engineer
# 192702    Data Scientist               Customer Experience Insights Analyst
# 340092    Data Scientist                              Data Scientist (D168)
# 734083      Data Analyst  Lead Data Analyst - Accounting & Internal Cont...
# 454158    Data Scientist                                     Data Scientist
# 368167      Data Analyst                            Data Management Analyst
# 298844    Data Scientist                            Data Science Generalist
#
#                                   job_location          job_via  \
# 548123                                Anywhere     via LinkedIn
# 139193                                Anywhere       via Get.It
# 416566                               Hong Kong  via Trabajo.org
# 363968                        Ostrava, Czechia   via Talent.com
# 192702  Quezon City, Metro Manila, Philippines  via Trabajo.org
# 340092                         Santiago, Chile     via Sercanto
# 734083                                Anywhere     via LinkedIn
# 454158                            Columbus, OH  via SimplyHired
# 368167                          Washington, DC     via LinkedIn
# 298844               Mexico City, CDMX, Mexico  via Trabajo.org
#
#        job_schedule_type  job_work_from_home          search_location  \
# 548123         Full-time                True                    India
# 139193         Full-time                True  New York, United States
# 416566         Full-time               False                Hong Kong
# 363968         Full-time               False                  Czechia
# 192702         Full-time               False              Philippines
# 340092         Full-time               False                    Chile
# 734083         Full-time                True                   Canada
# 454158        Contractor               False  Illinois, United States
# 368167         Full-time               False  New York, United States
# 298844         Full-time               False                   Mexico
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 548123 2023-11-30 19:13:20                  False                 False
# 139193 2023-12-16 08:00:01                  False                  True
# 416566 2023-01-07 16:22:51                  False                 False
# 363968 2023-08-06 00:15:30                   True                 False
# 192702 2023-12-22 15:21:25                  False                 False
# 340092 2023-05-07 23:38:18                  False                 False
# 734083 2023-08-29 21:44:15                  False                 False
# 454158 2023-01-31 14:04:21                  False                 False
# 368167 2023-05-26 23:00:38                  False                  True
# 298844 2023-02-18 17:19:33                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 548123          India        None         115000.0            45.98
# 139193  United States        year          50000.0            45.98
# 416566      Hong Kong        None         115000.0            45.98
# 363968        Czechia        None         115000.0            45.98
# 192702    Philippines        None         115000.0            45.98
# 340092          Chile        None         115000.0            45.98
# 734083         Canada        None         115000.0            45.98
# 454158  United States        None         115000.0            45.98
# 368167  United States        None         115000.0            45.98
# 298844         Mexico        None         115000.0            45.98
#
#                                      company_name  \
# 548123                       Prometrics Solutions
# 139193            Get It Recruit - Transportation
# 416566            Kroll Associates (Asia) Limited
# 363968                            Blue Media S.A.
# 192702                                   Manulife
# 340092                      Komatsu Cummins Chile
# 734083                                  Thumbtack
# 454158                          Devcare Solutions
# 368167  CGS Federal (Contact Government Services)
# 298844                                      Aviva
#
#                                                job_skills  \
# 548123                 ['sql', 'python', 'gcp', 'looker']
# 139193    ['python', 'r', 'excel', 'tableau', 'power bi']
# 416566                                    ['go', 'excel']
# 363968  ['sql', 'scala', 'java', 'python', 'aws', 'sno...
# 192702  ['sql', 'tableau', 'power bi', 'excel', 'sprea...
# 340092                       ['python', 'azure', 'excel']
# 734083  ['sql', 'excel', 'tableau', 'looker', 'powerpo...
# 454158                           ['r', 'python', 'spark']
# 368167                                               None
# 298844                                               None
#
#                                           job_type_skills
# 548123  {'analyst_tools': ['looker'], 'cloud': ['gcp']...
# 139193  {'analyst_tools': ['excel', 'tableau', 'power ...
# 416566  {'analyst_tools': ['excel'], 'programming': ['...
# 363968  {'cloud': ['aws', 'snowflake', 'redshift', 'da...
# 192702  {'analyst_tools': ['tableau', 'power bi', 'exc...
# 340092  {'analyst_tools': ['excel'], 'cloud': ['azure'...
# 734083  {'analyst_tools': ['excel', 'tableau', 'looker...
# 454158  {'libraries': ['spark'], 'programming': ['r', ...
# 368167                                               None
# 298844                                               None

# %% [markdown]
# # COPY( )

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original=dataset['train'].to_pandas()

# %%
df_altered = df_original

# %%
df_altered
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0       2023-06-16 13:44:15                  False                 False
# 1       2023-01-14 13:18:07                  False                 False
# 2       2023-10-10 13:14:55                  False                 False
# 3       2023-07-04 13:01:41                   True                 False
# 4       2023-08-07 14:29:36                  False                 False
# ...                     ...                    ...                   ...
# 785736  2023-03-13 06:16:16                  False                 False
# 785737  2023-03-12 06:18:18                  False                 False
# 785738  2023-03-12 06:32:36                  False                 False
# 785739  2023-03-12 06:32:15                  False                 False
# 785740  2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
medain_salary = df_altered['salary_year_avg'].median()

# %%
medain_salary
df_altered['salary_year_avg']=df_altered['salary_year_avg'].fillna(medain_salary)

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
id(df_original)
# Out:
# 1835472362752

# %%
id(df_altered)
# Out:
# 1835472362752

# %%
id(df_original)==id(df_altered)
# Out:
# True

# %% [markdown]
# #Each variable should have unique id so that we use copy()

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original=dataset['train'].to_pandas()

# %%
df_altered=df_original.copy()

# %%
print('id of df_original:', id(df_original))
print('id of df_altered:', id(df_altered))
print('Are these two data frames are same:', id(df_original) ==id(df_altered))
# Out:
# id of df_original: 1833806324384
# id of df_altered: 1835092059744
# Are these two data frames are same: False

# %%
medain_salary
df_altered['salary_year_avg']=df_altered['salary_year_avg'].fillna(medain_salary)
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# #NOW both id's and values are not same for this we use copy()

# %% [markdown]
# # Pandas: pivot tables
#   counts of job titles

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df.pivot_table(index='job_title_short', aggfunc='size')
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
df.groupby('job_title_short').size()
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
df.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc='median')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
df.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# MEDIAN SALARY ANALYSIS BY COUNTRY

# %%
df.pivot_table(values='salary_year_avg', index='job_country', columns='job_title_short', aggfunc='median')
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       NaN             NaN      49950.00
# Algeria                       NaN             NaN      44100.00
# Argentina                 71100.0        197500.0      92771.75
# Armenia                       NaN             NaN     100500.00
# Australia                 70000.0        110000.0     109500.00
# ...                           ...             ...           ...
# Uruguay                       NaN             NaN     100500.00
# Uzbekistan                    NaN             NaN           NaN
# Vietnam                   79200.0             NaN      75550.00
# Zambia                        NaN             NaN           NaN
# Zimbabwe                      NaN             NaN      63000.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN        69981.25                        NaN
# Algeria                45000.0             NaN                        NaN
# Argentina              96773.0        71000.00                   101029.0
# Armenia                48750.0             NaN                    87021.0
# Australia             106712.5       139216.00                   101029.0
# ...                        ...             ...                        ...
# Uruguay                    NaN             NaN                    50000.0
# Uzbekistan                 NaN        30750.00                        NaN
# Vietnam                96773.0        70000.00                    57600.0
# Zambia                     NaN        90670.00                        NaN
# Zimbabwe                   NaN        69085.00                        NaN
#
# job_title_short  Senior Data Analyst  Senior Data Engineer  \
# job_country
# Albania                          NaN                   NaN
# Algeria                          NaN                   NaN
# Argentina                        NaN              147500.0
# Armenia                          NaN                   NaN
# Australia                    50640.0              147500.0
# ...                              ...                   ...
# Uruguay                          NaN                   NaN
# Uzbekistan                       NaN                   NaN
# Vietnam                     105837.5              147500.0
# Zambia                           NaN                   NaN
# Zimbabwe                         NaN                   NaN
#
# job_title_short  Senior Data Scientist  Software Engineer
# job_country
# Albania                       157500.0                NaN
# Algeria                            NaN                NaN
# Argentina                          NaN           174500.0
# Armenia                            NaN                NaN
# Australia                     157500.0           118350.0
# ...                                ...                ...
# Uruguay                        57500.0                NaN
# Uzbekistan                         NaN                NaN
# Vietnam                        79200.0            53600.0
# Zambia                             NaN                NaN
# Zimbabwe                           NaN                NaN
#
# [108 rows x 10 columns]

# %%
top_countries=df['job_country'].value_counts()
top_countries
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Mauritania             3
# Lesotho                3
# Bhutan                 3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
top_countries=df['job_country'].value_counts().head(5).index
top_countries
# Out:
# Index(['United States', 'India', 'United Kingdom', 'France', 'Germany'], dtype='object', name='job_country')

# %%
top_countries=df['job_country'].value_counts().head(5).index

df_job_country_salary= df.pivot_table(
    values= 'salary_year_avg',
    index= 'job_country',
    columns='job_title_short',
    aggfunc='median'
)

df_job_country_salary= df_job_country_salary.loc[top_countries]

job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist']

df_job_country_salary=df_job_country_salary[job_titles]

df_job_country_salary.plot(kind='bar')
# Out:
# <Axes: xlabel='job_country'>

# %%
df_job_country_salary.plot(kind='bar')
plt.ylabel('median salary ($USD)')
plt.xlabel('')
plt.title('Median salary by country and job titles')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # Reset Index()

# %%
df.index.name = 'job_index'

# %%
df_India = df[df['job_country']== 'India']

# %%
df_India.head()
# Out:
#                 job_title_short                                    job_title  \
# job_index
# 16                Data Engineer                            Big Data Engineer
# 19               Data Scientist                               Data Scientist
# 29               Data Scientist                               Data Scientist
# 38                 Data Analyst        Data Quality and Governance Analyst 1
# 42         Senior Data Engineer  Senior Data Engineer(Python)-1563,1637&1633
#
#                          job_location  \
# job_index
# 16           Pune, Maharashtra, India
# 19           Pune, Maharashtra, India
# 29           Pune, Maharashtra, India
# 38                              India
# 42         Chennai, Tamil Nadu, India
#
#                                                      job_via  \
# job_index
# 16                                              via LinkedIn
# 19                                                via Indeed
# 29                                                via Exusia
# 38                                           via Trabajo.org
# 42         via HR Software For Growing Businesses | Fresh...
#
#           job_schedule_type  job_work_from_home search_location  \
# job_index
# 16                Full-time               False           India
# 19                Full-time               False           India
# 29                Full-time               False           India
# 38                Full-time               False           India
# 42                Full-time               False           India
#
#               job_posted_date  job_no_degree_mention  job_health_insurance  \
# job_index
# 16        2023-06-15 13:28:03                  False                 False
# 19        2023-04-26 13:20:12                  False                 False
# 29        2023-03-26 13:16:20                  False                 False
# 38        2023-07-23 13:24:57                  False                 False
# 42        2023-11-10 13:30:41                   True                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 16              India        None              NaN              NaN
# 19              India        None              NaN              NaN
# 29              India        None              NaN              NaN
# 38              India        None              NaN              NaN
# 42              India        None              NaN              NaN
#
#                          company_name  \
# job_index
# 16              Hexaware Technologies
# 19                  Bitwise Solutions
# 29                             Exusia
# 38         Jones Lang LaSalle IP, Inc
# 42                              CESIT
#
#                                                   job_skills  \
# job_index
# 16         ['powershell', 'python', 'sql', 'mysql', 'sql ...
# 19         ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 29                                                      None
# 38         ['sql', 'python', 'databricks', 'power bi', 'e...
# 42         ['python', 'sql', 'aws', 'pyspark', 'docker', ...
#
#                                              job_type_skills
# job_index
# 16         {'cloud': ['databricks', 'azure'], 'databases'...
# 19         {'analyst_tools': ['tableau'], 'libraries': ['...
# 29                                                      None
# 38         {'analyst_tools': ['power bi', 'excel', 'word'...
# 42         {'async': ['jira'], 'cloud': ['aws'], 'librari...

# %%
df_India.reset_index(inplace=True)
df_India
# Out:
#        job_index       job_title_short  \
# 0             16         Data Engineer
# 1             19        Data Scientist
# 2             29        Data Scientist
# 3             38          Data Analyst
# 4             42  Senior Data Engineer
# ...          ...                   ...
# 51083     785712         Data Engineer
# 51084     785715          Data Analyst
# 51085     785716     Software Engineer
# 51086     785718      Business Analyst
# 51087     785740     Software Engineer
#
#                                                job_title  \
# 0                                      Big Data Engineer
# 1                                         Data Scientist
# 2                                         Data Scientist
# 3                  Data Quality and Governance Analyst 1
# 4            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                  ...
# 51083                     India - Collections Analyst II
# 51084  Amul Careers 2023 - Apply Online - Data Analys...
# 51085                        Application Support Analyst
# 51086                      Senior Performance QA Analyst
# 51087                                 AWS System Analyst
#
#                      job_location  \
# 0        Pune, Maharashtra, India
# 1        Pune, Maharashtra, India
# 2        Pune, Maharashtra, India
# 3                           India
# 4      Chennai, Tamil Nadu, India
# ...                           ...
# 51083                       India
# 51084                       India
# 51085                       India
# 51086                       India
# 51087                       India
#
#                                                  job_via job_schedule_type  \
# 0                                           via LinkedIn         Full-time
# 1                                             via Indeed         Full-time
# 2                                             via Exusia         Full-time
# 3                                        via Trabajo.org         Full-time
# 4      via HR Software For Growing Businesses | Fresh...         Full-time
# ...                                                  ...               ...
# 51083                                melalui BeBee India   Pekerjaan tetap
# 51084  melalui Jobsleworld - Jobs In India - Job Vaca...   Pekerjaan tetap
# 51085                                melalui BeBee India   Pekerjaan tetap
# 51086                                melalui BeBee India   Pekerjaan tetap
# 51087                                     melalui Trigyn   Pekerjaan tetap
#
#        job_work_from_home search_location     job_posted_date  \
# 0                   False           India 2023-06-15 13:28:03
# 1                   False           India 2023-04-26 13:20:12
# 2                   False           India 2023-03-26 13:16:20
# 3                   False           India 2023-07-23 13:24:57
# 4                   False           India 2023-11-10 13:30:41
# ...                   ...             ...                 ...
# 51083               False           India 2023-03-13 06:16:31
# 51084               False           India 2023-03-13 06:16:28
# 51085               False           India 2023-03-13 06:16:31
# 51086               False           India 2023-03-13 06:16:28
# 51087               False           India 2023-03-13 06:16:31
#
#        job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 0                      False                 False       India        None
# 1                      False                 False       India        None
# 2                      False                 False       India        None
# 3                      False                 False       India        None
# 4                       True                 False       India        None
# ...                      ...                   ...         ...         ...
# 51083                  False                 False       India        None
# 51084                  False                 False       India        None
# 51085                  False                 False       India        None
# 51086                  False                 False       India        None
# 51087                  False                 False       India        None
#
#        salary_year_avg  salary_hour_avg                  company_name  \
# 0                  NaN              NaN         Hexaware Technologies
# 1                  NaN              NaN             Bitwise Solutions
# 2                  NaN              NaN                        Exusia
# 3                  NaN              NaN    Jones Lang LaSalle IP, Inc
# 4                  NaN              NaN                         CESIT
# ...                ...              ...                           ...
# 51083              NaN              NaN  Varite India Private Limited
# 51084              NaN              NaN                          Amul
# 51085              NaN              NaN            CompuGroup Medical
# 51086              NaN              NaN               Diebold Nixdorf
# 51087              NaN              NaN                        Trigyn
#
#                                               job_skills  \
# 0      ['powershell', 'python', 'sql', 'mysql', 'sql ...
# 1      ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 2                                                   None
# 3      ['sql', 'python', 'databricks', 'power bi', 'e...
# 4      ['python', 'sql', 'aws', 'pyspark', 'docker', ...
# ...                                                  ...
# 51083                                  ['excel', 'flow']
# 51084                                               None
# 51085                                      ['c#', 'sql']
# 51086                                               None
# 51087                                    ['aws', 'flow']
#
#                                          job_type_skills
# 0      {'cloud': ['databricks', 'azure'], 'databases'...
# 1      {'analyst_tools': ['tableau'], 'libraries': ['...
# 2                                                   None
# 3      {'analyst_tools': ['power bi', 'excel', 'word'...
# 4      {'async': ['jira'], 'cloud': ['aws'], 'librari...
# ...                                                  ...
# 51083    {'analyst_tools': ['excel'], 'other': ['flow']}
# 51084                                               None
# 51085                     {'programming': ['c#', 'sql']}
# 51086                                               None
# 51087              {'cloud': ['aws'], 'other': ['flow']}
#
# [51088 rows x 18 columns]

# %% [markdown]
# # SET INDEX()

# %%
df_India.set_index('job_index' , inplace=True)

# %%
df_India
# Out:
#                 job_title_short  \
# job_index
# 16                Data Engineer
# 19               Data Scientist
# 29               Data Scientist
# 38                 Data Analyst
# 42         Senior Data Engineer
# ...                         ...
# 785712            Data Engineer
# 785715             Data Analyst
# 785716        Software Engineer
# 785718         Business Analyst
# 785740        Software Engineer
#
#                                                    job_title  \
# job_index
# 16                                         Big Data Engineer
# 19                                            Data Scientist
# 29                                            Data Scientist
# 38                     Data Quality and Governance Analyst 1
# 42               Senior Data Engineer(Python)-1563,1637&1633
# ...                                                      ...
# 785712                        India - Collections Analyst II
# 785715     Amul Careers 2023 - Apply Online - Data Analys...
# 785716                           Application Support Analyst
# 785718                         Senior Performance QA Analyst
# 785740                                    AWS System Analyst
#
#                          job_location  \
# job_index
# 16           Pune, Maharashtra, India
# 19           Pune, Maharashtra, India
# 29           Pune, Maharashtra, India
# 38                              India
# 42         Chennai, Tamil Nadu, India
# ...                               ...
# 785712                          India
# 785715                          India
# 785716                          India
# 785718                          India
# 785740                          India
#
#                                                      job_via  \
# job_index
# 16                                              via LinkedIn
# 19                                                via Indeed
# 29                                                via Exusia
# 38                                           via Trabajo.org
# 42         via HR Software For Growing Businesses | Fresh...
# ...                                                      ...
# 785712                                   melalui BeBee India
# 785715     melalui Jobsleworld - Jobs In India - Job Vaca...
# 785716                                   melalui BeBee India
# 785718                                   melalui BeBee India
# 785740                                        melalui Trigyn
#
#           job_schedule_type  job_work_from_home search_location  \
# job_index
# 16                Full-time               False           India
# 19                Full-time               False           India
# 29                Full-time               False           India
# 38                Full-time               False           India
# 42                Full-time               False           India
# ...                     ...                 ...             ...
# 785712      Pekerjaan tetap               False           India
# 785715      Pekerjaan tetap               False           India
# 785716      Pekerjaan tetap               False           India
# 785718      Pekerjaan tetap               False           India
# 785740      Pekerjaan tetap               False           India
#
#               job_posted_date  job_no_degree_mention  job_health_insurance  \
# job_index
# 16        2023-06-15 13:28:03                  False                 False
# 19        2023-04-26 13:20:12                  False                 False
# 29        2023-03-26 13:16:20                  False                 False
# 38        2023-07-23 13:24:57                  False                 False
# 42        2023-11-10 13:30:41                   True                 False
# ...                       ...                    ...                   ...
# 785712    2023-03-13 06:16:31                  False                 False
# 785715    2023-03-13 06:16:28                  False                 False
# 785716    2023-03-13 06:16:31                  False                 False
# 785718    2023-03-13 06:16:28                  False                 False
# 785740    2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 16              India        None              NaN              NaN
# 19              India        None              NaN              NaN
# 29              India        None              NaN              NaN
# 38              India        None              NaN              NaN
# 42              India        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785712          India        None              NaN              NaN
# 785715          India        None              NaN              NaN
# 785716          India        None              NaN              NaN
# 785718          India        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                            company_name  \
# job_index
# 16                Hexaware Technologies
# 19                    Bitwise Solutions
# 29                               Exusia
# 38           Jones Lang LaSalle IP, Inc
# 42                                CESIT
# ...                                 ...
# 785712     Varite India Private Limited
# 785715                             Amul
# 785716               CompuGroup Medical
# 785718                  Diebold Nixdorf
# 785740                           Trigyn
#
#                                                   job_skills  \
# job_index
# 16         ['powershell', 'python', 'sql', 'mysql', 'sql ...
# 19         ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 29                                                      None
# 38         ['sql', 'python', 'databricks', 'power bi', 'e...
# 42         ['python', 'sql', 'aws', 'pyspark', 'docker', ...
# ...                                                      ...
# 785712                                     ['excel', 'flow']
# 785715                                                  None
# 785716                                         ['c#', 'sql']
# 785718                                                  None
# 785740                                       ['aws', 'flow']
#
#                                              job_type_skills
# job_index
# 16         {'cloud': ['databricks', 'azure'], 'databases'...
# 19         {'analyst_tools': ['tableau'], 'libraries': ['...
# 29                                                      None
# 38         {'analyst_tools': ['power bi', 'excel', 'word'...
# 42         {'async': ['jira'], 'cloud': ['aws'], 'librari...
# ...                                                      ...
# 785712       {'analyst_tools': ['excel'], 'other': ['flow']}
# 785715                                                  None
# 785716                        {'programming': ['c#', 'sql']}
# 785718                                                  None
# 785740                 {'cloud': ['aws'], 'other': ['flow']}
#
# [51088 rows x 17 columns]

# %% [markdown]
# # Sort Index()

# %%
median_pivot= df_India.pivot_table(values= 'salary_year_avg', index='job_title_short', aggfunc=['median', 'min', 'max'])
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  64800.0         43200.0        142025.0
# Data Analyst                     100500.0         32400.0        650000.0
# Data Engineer                    147500.0         43200.0        249000.0
# Data Scientist                   114008.0         43200.0        204381.0
# Machine Learning Engineer         79200.0         32500.0        267000.0
# Senior Data Analyst              111175.0         64800.0        177283.0
# Senior Data Engineer             147500.0         35000.0        181765.0
# Senior Data Scientist            149653.0         64800.0        170575.0
# Software Engineer                 79200.0         44418.5        200000.0

# %%
median_pivot.sort_values(by=('median', 'salary_year_avg') , ascending=False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            149653.0         64800.0        170575.0
# Data Engineer                    147500.0         43200.0        249000.0
# Senior Data Engineer             147500.0         35000.0        181765.0
# Data Scientist                   114008.0         43200.0        204381.0
# Senior Data Analyst              111175.0         64800.0        177283.0
# Data Analyst                     100500.0         32400.0        650000.0
# Machine Learning Engineer         79200.0         32500.0        267000.0
# Software Engineer                 79200.0         44418.5        200000.0
# Business Analyst                  64800.0         43200.0        142025.0

# %%
median_pivot.sort_index(inplace=True)

# %%
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  64800.0         43200.0        142025.0
# Data Analyst                     100500.0         32400.0        650000.0
# Data Engineer                    147500.0         43200.0        249000.0
# Data Scientist                   114008.0         43200.0        204381.0
# Machine Learning Engineer         79200.0         32500.0        267000.0
# Senior Data Analyst              111175.0         64800.0        177283.0
# Senior Data Engineer             147500.0         35000.0        181765.0
# Senior Data Scientist            149653.0         64800.0        170575.0
# Software Engineer                 79200.0         44418.5        200000.0

# %%
median_pivot.sort_values(by=('job_title_short') , ascending=False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Software Engineer                 79200.0         44418.5        200000.0
# Senior Data Scientist            149653.0         64800.0        170575.0
# Senior Data Engineer             147500.0         35000.0        181765.0
# Senior Data Analyst              111175.0         64800.0        177283.0
# Machine Learning Engineer         79200.0         32500.0        267000.0
# Data Scientist                   114008.0         43200.0        204381.0
# Data Engineer                    147500.0         43200.0        249000.0
# Data Analyst                     100500.0         32400.0        650000.0
# Business Analyst                  64800.0         43200.0        142025.0

# %% [markdown]
# # Excercise - Analyzing Data Science Job Demand

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df_India=df[df['job_country']== 'India'].copy()

# %%
df_India['job_posted_month']=df_India['job_posted_date'].dt.strftime('%B')
df_India
# Out:
#              job_title_short  \
# 16             Data Engineer
# 19            Data Scientist
# 29            Data Scientist
# 38              Data Analyst
# 42      Senior Data Engineer
# ...                      ...
# 785712         Data Engineer
# 785715          Data Analyst
# 785716     Software Engineer
# 785718      Business Analyst
# 785740     Software Engineer
#
#                                                 job_title  \
# 16                                      Big Data Engineer
# 19                                         Data Scientist
# 29                                         Data Scientist
# 38                  Data Quality and Governance Analyst 1
# 42            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                   ...
# 785712                     India - Collections Analyst II
# 785715  Amul Careers 2023 - Apply Online - Data Analys...
# 785716                        Application Support Analyst
# 785718                      Senior Performance QA Analyst
# 785740                                 AWS System Analyst
#
#                       job_location  \
# 16        Pune, Maharashtra, India
# 19        Pune, Maharashtra, India
# 29        Pune, Maharashtra, India
# 38                           India
# 42      Chennai, Tamil Nadu, India
# ...                            ...
# 785712                       India
# 785715                       India
# 785716                       India
# 785718                       India
# 785740                       India
#
#                                                   job_via job_schedule_type  \
# 16                                           via LinkedIn         Full-time
# 19                                             via Indeed         Full-time
# 29                                             via Exusia         Full-time
# 38                                        via Trabajo.org         Full-time
# 42      via HR Software For Growing Businesses | Fresh...         Full-time
# ...                                                   ...               ...
# 785712                                melalui BeBee India   Pekerjaan tetap
# 785715  melalui Jobsleworld - Jobs In India - Job Vaca...   Pekerjaan tetap
# 785716                                melalui BeBee India   Pekerjaan tetap
# 785718                                melalui BeBee India   Pekerjaan tetap
# 785740                                     melalui Trigyn   Pekerjaan tetap
#
#         job_work_from_home search_location     job_posted_date  \
# 16                   False           India 2023-06-15 13:28:03
# 19                   False           India 2023-04-26 13:20:12
# 29                   False           India 2023-03-26 13:16:20
# 38                   False           India 2023-07-23 13:24:57
# 42                   False           India 2023-11-10 13:30:41
# ...                    ...             ...                 ...
# 785712               False           India 2023-03-13 06:16:31
# 785715               False           India 2023-03-13 06:16:28
# 785716               False           India 2023-03-13 06:16:31
# 785718               False           India 2023-03-13 06:16:28
# 785740               False           India 2023-03-13 06:16:31
#
#         job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 16                      False                 False       India        None
# 19                      False                 False       India        None
# 29                      False                 False       India        None
# 38                      False                 False       India        None
# 42                       True                 False       India        None
# ...                       ...                   ...         ...         ...
# 785712                  False                 False       India        None
# 785715                  False                 False       India        None
# 785716                  False                 False       India        None
# 785718                  False                 False       India        None
# 785740                  False                 False       India        None
#
#         salary_year_avg  salary_hour_avg                  company_name  \
# 16                  NaN              NaN         Hexaware Technologies
# 19                  NaN              NaN             Bitwise Solutions
# 29                  NaN              NaN                        Exusia
# 38                  NaN              NaN    Jones Lang LaSalle IP, Inc
# 42                  NaN              NaN                         CESIT
# ...                 ...              ...                           ...
# 785712              NaN              NaN  Varite India Private Limited
# 785715              NaN              NaN                          Amul
# 785716              NaN              NaN            CompuGroup Medical
# 785718              NaN              NaN               Diebold Nixdorf
# 785740              NaN              NaN                        Trigyn
#
#                                                job_skills  \
# 16      ['powershell', 'python', 'sql', 'mysql', 'sql ...
# 19      ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 29                                                   None
# 38      ['sql', 'python', 'databricks', 'power bi', 'e...
# 42      ['python', 'sql', 'aws', 'pyspark', 'docker', ...
# ...                                                   ...
# 785712                                  ['excel', 'flow']
# 785715                                               None
# 785716                                      ['c#', 'sql']
# 785718                                               None
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills job_posted_month
# 16      {'cloud': ['databricks', 'azure'], 'databases'...             June
# 19      {'analyst_tools': ['tableau'], 'libraries': ['...            April
# 29                                                   None            March
# 38      {'analyst_tools': ['power bi', 'excel', 'word'...             July
# 42      {'async': ['jira'], 'cloud': ['aws'], 'librari...         November
# ...                                                   ...              ...
# 785712    {'analyst_tools': ['excel'], 'other': ['flow']}            March
# 785715                                               None            March
# 785716                     {'programming': ['c#', 'sql']}            March
# 785718                                               None            March
# 785740              {'cloud': ['aws'], 'other': ['flow']}            March
#
# [51088 rows x 18 columns]

# %%
df_India_pivot= df_India.pivot_table(index='job_posted_month', columns= 'job_title_short',aggfunc='size')

# %%
df_India_pivot.reset_index(inplace=True)
df_India_pivot['month_no']= pd.to_datetime(df_India_pivot['job_posted_month'],format='%B').dt.month
df_India_pivot.sort_values('month_no', inplace=True)
df_India_pivot.set_index('job_posted_month',inplace=True)
df_India_pivot.drop(columns='month_no', inplace=True)

# %%
df_India_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        175              31           628
# February                       143              35           433
# March                          116              37           422
# April                          170              32           418
# May                            103              14           278
# June                           146              26           367
# July                           142              25           457
# August                         189              25           618
# September                      155              34           630
# October                        170              36           500
# November                       192              29           722
# December                       186              27           648
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    2132            1444                         70
# February                   1631             932                         42
# March                      1591            1005                         34
# April                      1566             946                         54
# May                        1384             837                         31
# June                       1632            1129                         41
# July                       1528            1123                         54
# August                     1407            1157                         47
# September                  1508             984                         67
# October                    1476             902                         85
# November                   1743            1614                         52
# December                   1464            1206                         94
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                           127                   448
# February                           94                   313
# March                              96                   351
# April                              86                   375
# May                                59                   329
# June                               66                   427
# July                               75                   359
# August                            126                   343
# September                          85                   324
# October                            67                   318
# November                          125                   423
# December                           77                   343
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# January                             269                192
# February                            165                157
# March                               194                180
# April                               194                169
# May                                 134                 98
# June                                238                125
# July                                204                155
# August                              235                148
# September                           195                132
# October                             180                167
# November                            278                139
# December                            200                133

# %%
df_India_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
top_3=df_India['job_title_short'].value_counts().head(3)
top_3
# Out:
# job_title_short
# Data Engineer     19062
# Data Scientist    13279
# Data Analyst       6121
# Name: count, dtype: int64

# %%
top_3=df_India['job_title_short'].value_counts().head(3)
top_3.index.tolist()
# Out:
# ['Data Engineer', 'Data Scientist', 'Data Analyst']

# %%
top_3=df_India['job_title_short'].value_counts().head(3)
top_3=top_3.index.tolist()

# %%
df_India_pivot[top_3].plot(kind='line')
plt.title('monthly job posting for Top Data Jobs in the India')
plt.xlabel('2023')
plt.ylabel('job counts')
plt.legend()
plt.show()

# %% [markdown]
# # Pandas: Concat Data Frames

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills job_posted_month
# 0                                                    None              Jun
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...              Jan
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...              Oct
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...              Jul
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...              Aug
# ...                                                   ...              ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...              Mar
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...              Mar
# 785738         {'analyst_tools': ['powerpoint', 'excel']}              Mar
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...              Mar
# 785740              {'cloud': ['aws'], 'other': ['flow']}              Mar
#
# [785741 rows x 18 columns]

# %%
months=df['job_posted_month'].unique()
dict_months = {month : df[df['job_posted_month'] == month] for month in months}
dict_months['Jan']
# Out:
#           job_title_short                                  job_title  \
# 1            Data Analyst                               Data Analyst
# 20         Data Scientist                             Data Scientist
# 39          Data Engineer                              Data Engineer
# 53          Data Engineer                              Data Engineer
# 55         Data Scientist                             Data Scientist
# ...                   ...                                        ...
# 785699  Software Engineer                        Simulation Engineer
# 785700      Data Engineer                       Data Engineer Ssr/Sr
# 785703       Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704   Business Analyst                           Business Analyst
# 785705       Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                  job_location             job_via  \
# 1                Guadalajara, Jalisco, Mexico    via BeBee México
# 20                          Zaventem, Belgium  via BeBee Belgique
# 39                             Fort Worth, TX        via LinkedIn
# 53                              San Mateo, CA        via LinkedIn
# 55      São Paulo, State of São Paulo, Brazil           via BeBee
# ...                                       ...                 ...
# 785699                        Prague, Czechia     via Trabajo.org
# 785700              Mexico City, CDMX, Mexico     via Trabajo.org
# 785703                               Anywhere        via Snagajob
# 785704                        Prague, Czechia     via Trabajo.org
# 785705                            Oakland, CA        via Snagajob
#
#        job_schedule_type  job_work_from_home            search_location  \
# 1              Full-time               False                     Mexico
# 20             Full-time               False                    Belgium
# 39             Full-time               False       Texas, United States
# 53             Full-time               False  California, United States
# 55             Full-time               False                     Brazil
# ...                  ...                 ...                        ...
# 785699         Full-time               False                    Czechia
# 785700         Full-time               False                     Mexico
# 785703         Full-time                True       Texas, United States
# 785704         Full-time               False                    Czechia
# 785705         Full-time               False  California, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1      2023-01-14 13:18:07                  False                 False
# 20     2023-01-31 13:53:38                  False                 False
# 39     2023-01-25 13:24:01                  False                 False
# 53     2023-01-28 13:07:30                  False                  True
# 55     2023-01-03 23:02:27                  False                 False
# ...                    ...                    ...                   ...
# 785699 2023-01-16 06:35:30                  False                 False
# 785700 2023-01-12 06:19:55                   True                 False
# 785703 2023-01-28 06:02:55                   True                 False
# 785704 2023-01-16 06:35:20                  False                 False
# 785705 2023-01-09 06:00:25                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 1              Mexico        None              NaN              NaN
# 20            Belgium        None              NaN              NaN
# 39      United States        None              NaN              NaN
# 53      United States        None              NaN              NaN
# 55             Brazil        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785699        Czechia        None              NaN              NaN
# 785700         Mexico        None              NaN              NaN
# 785703  United States        None              NaN              NaN
# 785704        Czechia        None              NaN              NaN
# 785705  United States        None              NaN              NaN
#
#                        company_name  \
# 1        Hewlett Packard Enterprise
# 20                         Devoteam
# 39                   Programmers.io
# 53                          Verkada
# 55                             Mars
# ...                             ...
# 785699        Ricardo Prague s.r.o.
# 785700                        Tsoft
# 785703  Axelon Services Corporation
# 785704                  Cleverlance
# 785705             PG&E Corporation
#
#                                                job_skills  \
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 20      ['r', 'python', 'sql', 'pandas', 'numpy', 'sci...
# 39                                      ['sql', 'python']
# 53                     ['sql', 'python', 'aws', 'looker']
# 55                             ['python', 'sql', 'azure']
# ...                                                   ...
# 785699                            ['powerpoint', 'excel']
# 785700  ['python', 'r', 'azure', 'aws', 'gcp', 'spark'...
# 785703                                               None
# 785704                                               None
# 785705                       ['sql', 'python', 'tableau']
#
#                                           job_type_skills job_posted_month
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...              Jan
# 20      {'libraries': ['pandas', 'numpy', 'scikit-lear...              Jan
# 39                     {'programming': ['sql', 'python']}              Jan
# 53      {'analyst_tools': ['looker'], 'cloud': ['aws']...              Jan
# 55      {'cloud': ['azure'], 'programming': ['python',...              Jan
# ...                                                   ...              ...
# 785699         {'analyst_tools': ['powerpoint', 'excel']}              Jan
# 785700  {'cloud': ['azure', 'aws', 'gcp'], 'libraries'...              Jan
# 785703                                               None              Jan
# 785704                                               None              Jan
# 785705  {'analyst_tools': ['tableau'], 'programming': ...              Jan
#
# [91822 rows x 18 columns]

# %% [markdown]
# BOSS NEEDS QUATER 1 2024

# %%
df_q1= pd.concat([dict_months['Jan'], dict_months['Feb'], dict_months['Mar']], ignore_index=True  )

# %%
df_q1['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_posted_month'>

# %% [markdown]
# # Pandas: Exporting Data Frames

# %%
df_q1.head().to_clipboard(sep=",")

# %% [markdown]
# ,job_title_short,job_title,job_location,job_via,job_schedule_type,job_work_from_home,search_location,job_posted_date,job_no_degree_mention,job_health_insurance,job_country,salary_rate,salary_year_avg,salary_hour_avg,company_name,job_skills,job_type_skills,job_posted_month
# 0,Data Analyst,Data Analyst,"Guadalajara, Jalisco, Mexico",via BeBee México,Full-time,False,Mexico,2023-01-14 13:18:07,False,False,Mexico,,,,Hewlett Packard Enterprise,"['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']","{'analyst_tools': ['power bi', 'tableau'], 'programming': ['r', 'python', 'sql', 'nosql']}",Jan
# 1,Data Scientist,Data Scientist,"Zaventem, Belgium",via BeBee Belgique,Full-time,False,Belgium,2023-01-31 13:53:38,False,False,Belgium,,,,Devoteam,"['r', 'python', 'sql', 'pandas', 'numpy', 'scikit-learn', 'matplotlib', 'hadoop', 'spark']","{'libraries': ['pandas', 'numpy', 'scikit-learn', 'matplotlib', 'hadoop', 'spark'], 'programming': ['r', 'python', 'sql']}",Jan
# 2,Data Engineer,Data Engineer,"Fort Worth, TX",via LinkedIn,Full-time,False,"Texas, United States",2023-01-25 13:24:01,False,False,United States,,,,Programmers.io,"['sql', 'python']","{'programming': ['sql', 'python']}",Jan
# 3,Data Engineer,Data Engineer,"San Mateo, CA",via LinkedIn,Full-time,False,"California, United States",2023-01-28 13:07:30,False,True,United States,,,,Verkada,"['sql', 'python', 'aws', 'looker']","{'analyst_tools': ['looker'], 'cloud': ['aws'], 'programming': ['sql', 'python']}",Jan
# 4,Data Scientist,Data Scientist,"São Paulo, State of São Paulo, Brazil",via BeBee,Full-time,False,Brazil,2023-01-03 23:02:27,False,False,Brazil,,,,Mars,"['python', 'sql', 'azure']","{'cloud': ['azure'], 'programming': ['python', 'sql']}",Jan

# %%
df_q1.to_csv('quater_1.csv')

# %%
pd.read_csv('quater_1.csv', index_col=0)
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
#                                  job_location                    job_via  \
# 0                Guadalajara, Jalisco, Mexico           via BeBee México
# 1                           Zaventem, Belgium         via BeBee Belgique
# 2                              Fort Worth, TX               via LinkedIn
# 3                               San Mateo, CA               via LinkedIn
# 4       São Paulo, State of São Paulo, Brazil                  via BeBee
# ...                                       ...                        ...
# 220479                              Singapura        melalui Trabajo.org
# 220480                     Bad Rodach, Jerman  melalui BeBee Deutschland
# 220481                               Malaysia           melalui Ricebowl
# 220482    Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 220483                                  India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home            search_location  \
# 0              Full-time               False                     Mexico
# 1              Full-time               False                    Belgium
# 2              Full-time               False       Texas, United States
# 3              Full-time               False  California, United States
# 4              Full-time               False                     Brazil
# ...                  ...                 ...                        ...
# 220479   Pekerjaan tetap               False                  Singapore
# 220480   Pekerjaan tetap               False                    Germany
# 220481   Pekerjaan tetap               False                   Malaysia
# 220482   Pekerjaan tetap               False                      Sudan
# 220483   Pekerjaan tetap               False                      India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0       2023-01-14 13:18:07                  False                 False
# 1       2023-01-31 13:53:38                  False                 False
# 2       2023-01-25 13:24:01                  False                 False
# 3       2023-01-28 13:07:30                  False                  True
# 4       2023-01-03 23:02:27                  False                 False
# ...                     ...                    ...                   ...
# 220479  2023-03-13 06:16:16                  False                 False
# 220480  2023-03-12 06:18:18                  False                 False
# 220481  2023-03-12 06:32:36                  False                 False
# 220482  2023-03-12 06:32:15                  False                 False
# 220483  2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0              Mexico         NaN              NaN              NaN
# 1             Belgium         NaN              NaN              NaN
# 2       United States         NaN              NaN              NaN
# 3       United States         NaN              NaN              NaN
# 4              Brazil         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 220479      Singapore         NaN              NaN              NaN
# 220480        Germany         NaN              NaN              NaN
# 220481       Malaysia         NaN              NaN              NaN
# 220482          Sudan         NaN              NaN              NaN
# 220483          India         NaN              NaN              NaN
#
#                               company_name  \
# 0               Hewlett Packard Enterprise
# 1                                 Devoteam
# 2                           Programmers.io
# 3                                  Verkada
# 4                                     Mars
# ...                                    ...
# 220479  CAREERSTAR INTERNATIONAL PTE. LTD.
# 220480                    HABA FAMILYGROUP
# 220481               Lendlease Corporation
# 220482                         Capital One
# 220483                              Trigyn
#
#                                                job_skills  \
# 0       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 1       ['r', 'python', 'sql', 'pandas', 'numpy', 'sci...
# 2                                       ['sql', 'python']
# 3                      ['sql', 'python', 'aws', 'looker']
# 4                              ['python', 'sql', 'azure']
# ...                                                   ...
# 220479  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 220480                     ['sas', 'sas', 'sql', 'excel']
# 220481                            ['powerpoint', 'excel']
# 220482  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 220483                                    ['aws', 'flow']
#
#                                           job_type_skills job_posted_month
# 0       {'analyst_tools': ['power bi', 'tableau'], 'pr...              Jan
# 1       {'libraries': ['pandas', 'numpy', 'scikit-lear...              Jan
# 2                      {'programming': ['sql', 'python']}              Jan
# 3       {'analyst_tools': ['looker'], 'cloud': ['aws']...              Jan
# 4       {'cloud': ['azure'], 'programming': ['python',...              Jan
# ...                                                   ...              ...
# 220479  {'os': ['linux', 'unix'], 'other': ['kubernete...              Mar
# 220480  {'analyst_tools': ['sas', 'excel'], 'programmi...              Mar
# 220481         {'analyst_tools': ['powerpoint', 'excel']}              Mar
# 220482  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...              Mar
# 220483              {'cloud': ['aws'], 'other': ['flow']}              Mar
#
# [220484 rows x 18 columns]

# %% [markdown]
# # To Excel()

# %%
df_q1.to_excel('quater_1.xlsx')

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# # To Sql()

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///jobs.db')

df.to_sql('job_table', con=engine, if_exists='append', index=False)
# Out:
# 785741

# %% [markdown]
# # To Parquet()

# %%
df.to_parquet('jobs_data_parquet')

# %% [markdown]
# # To Pickle()

# %%
df.to_pickle('job_data.pkl')

# %% [markdown]
# # Apply() - Calculate Project Salary Next Year

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df['salary_year_avg']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 785736   NaN
# 785737   NaN
# 785738   NaN
# 785739   NaN
# 785740   NaN
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df[pd.notna(df['salary_year_avg'])]['salary_year_avg']
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %%
help(df.apply)
# Out:
# Help on method apply in module pandas.core.frame:
#
# apply(func: 'AggFuncType', axis: 'Axis' = 0, raw: 'bool' = False, result_type: "Literal['expand', 'reduce', 'broadcast'] | None" = None, args=(), by_row: "Literal[False, 'compat']" = 'compat', engine: "Literal['python', 'numba']" = 'python', engine_kwargs: 'dict[str, bool] | None' = None, **kwargs) method of pandas.core.frame.DataFrame instance
#     Apply a function along an axis of the DataFrame.
#
#     Objects passed to the function are Series objects whose index is
#     either the DataFrame's index (``axis=0``) or the DataFrame's columns
#     (``axis=1``). By default (``result_type=None``), the final return type
#     is inferred from the return type of the applied function. Otherwise,
#     it depends on the `result_type` argument.
#
#     Parameters
#     ----------
#     func : function
#         Function to apply to each column or row.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Axis along which the function is applied:
#
#         * 0 or 'index': apply function to each column.
#         * 1 or 'columns': apply function to each row.
#
#     raw : bool, default False
#         Determines if row or column is passed as a Series or ndarray object:
#
#         * ``False`` : passes each row or column as a Series to the
#           function.
#         * ``True`` : the passed function will receive ndarray objects
#           instead.
#           If you are just applying a NumPy reduction function this will
#           achieve much better performance.
#
#     result_type : {'expand', 'reduce', 'broadcast', None}, default None
#         These only act when ``axis=1`` (columns):
#
#         * 'expand' : list-like results will be turned into columns.
#         * 'reduce' : returns a Series if possible rather than expanding
#           list-like results. This is the opposite of 'expand'.
#         * 'broadcast' : results will be broadcast to the original shape
#           of the DataFrame, the original index and columns will be
#           retained.
#
#         The default behaviour (None) depends on the return value of the
#         applied function: list-like results will be returned as a Series
#         of those. However if the apply function returns a Series these
#         are expanded to columns.
#     args : tuple
#         Positional arguments to pass to `func` in addition to the
#         array/series.
#     by_row : False or "compat", default "compat"
#         Only has an effect when ``func`` is a listlike or dictlike of funcs
#         and the func isn't a string.
#         If "compat", will if possible first translate the func into pandas
#         methods (e.g. ``Series().apply(np.sum)`` will be translated to
#         ``Series().sum()``). If that doesn't work, will try call to apply again with
#         ``by_row=True`` and if that fails, will call apply again with
#         ``by_row=False`` (backward compatible).
#         If False, the funcs will be passed the whole Series at once.
#
#         .. versionadded:: 2.1.0
#
#     engine : {'python', 'numba'}, default 'python'
#         Choose between the python (default) engine or the numba engine in apply.
#
#         The numba engine will attempt to JIT compile the passed function,
#         which may result in speedups for large DataFrames.
#         It also supports the following engine_kwargs :
#
#         - nopython (compile the function in nopython mode)
#         - nogil (release the GIL inside the JIT compiled function)
#         - parallel (try to apply the function in parallel over the DataFrame)
#
#           Note: Due to limitations within numba/how pandas interfaces with numba,
#           you should only use this if raw=True
#
#         Note: The numba compiler only supports a subset of
#         valid Python/numpy operations.
#
#         Please read more about the `supported python features
#         <https://numba.pydata.org/numba-doc/dev/reference/pysupported.html>`_
#         and `supported numpy features
#         <https://numba.pydata.org/numba-doc/dev/reference/numpysupported.html>`_
#         in numba to learn what you can or cannot use in the passed function.
#
#         .. versionadded:: 2.2.0
#
#     engine_kwargs : dict
#         Pass keyword arguments to the engine.
#         This is currently only used by the numba engine,
#         see the documentation for the engine argument for more information.
#     **kwargs
#         Additional keyword arguments to pass as keywords arguments to
#         `func`.
#
#     Returns
#     -------
#     Series or DataFrame
#         Result of applying ``func`` along the given axis of the
#         DataFrame.
#
#     See Also
#     --------
#     DataFrame.map: For elementwise operations.
#     DataFrame.aggregate: Only perform aggregating type operations.
#     DataFrame.transform: Only perform transforming type operations.
#
#     Notes
#     -----
#     Functions that mutate the passed object can produce unexpected
#     behavior or errors and are not supported. See :ref:`gotchas.udf-mutation`
#     for more details.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame([[4, 9]] * 3, columns=['A', 'B'])
#     >>> df
#        A  B
#     0  4  9
#     1  4  9
#     2  4  9
#
#     Using a numpy universal function (in this case the same as
#     ``np.sqrt(df)``):
#
#     >>> df.apply(np.sqrt)
#          A    B
#     0  2.0  3.0
#     1  2.0  3.0
#     2  2.0  3.0
#
#     Using a reducing function on either axis
#
#     >>> df.apply(np.sum, axis=0)
#     A    12
#     B    27
#     dtype: int64
#
#     >>> df.apply(np.sum, axis=1)
#     0    13
#     1    13
#     2    13
#     dtype: int64
#
#     Returning a list-like will result in a Series
#
#     >>> df.apply(lambda x: [1, 2], axis=1)
#     0    [1, 2]
#     1    [1, 2]
#     2    [1, 2]
#     dtype: object
#
#     Passing ``result_type='expand'`` will expand list-like results
#     to columns of a Dataframe
#
#     >>> df.apply(lambda x: [1, 2], axis=1, result_type='expand')
#        0  1
#     0  1  2
#     1  1  2
#     2  1  2
#
#     Returning a Series inside the function is similar to passing
#     ``result_type='expand'``. The resulting column names
#     will be the Series index.
#
#     >>> df.apply(lambda x: pd.Series([1, 2], index=['foo', 'bar']), axis=1)
#        foo  bar
#     0    1    2
#     1    1    2
#     2    1    2
#
#     Passing ``result_type='broadcast'`` will ensure the same shape
#     result, whether list-like or scalar is returned by the function,
#     and broadcast it along the axis. The resulting column names will
#     be the originals.
#
#     >>> df.apply(lambda x: [1, 2], axis=1, result_type='broadcast')
#        A  B
#     0  1  2
#     1  1  2
#     2  1  2

# %%
df_salary= df[pd.notna(df['salary_year_avg'])].copy()

def projected_salary(salary):
    return salary * 1.03

df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(projected_salary)

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(lambda salary : salary *1.03)

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df_salary['salary_year_avg']=df_salary['salary_year_inflated']*1.03
df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28          116168.5500             112785.00
# 77          148526.0000             144200.00
# 92          127308.0000             123600.00
# 100         242120.7198             235068.66
# 109          94420.1000              91670.00
# ...                 ...                   ...
# 785624      147694.2544             143392.48
# 785641      159135.0000             154500.00
# 785648      235387.1875             228531.25
# 785682      167091.7500             162225.00
# 785692      167091.7500             162225.00
#
# [22003 rows x 2 columns]

# %% [markdown]
# # To Covert Str into a List

# %%
type(df['job_skills'][1])
# Out:
# str

# %%
import ast
type(ast.literal_eval(df['job_skills'][1]))
# Out:
# list

# %%
df[pd.isna(df['job_skills'])]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 21            Data Scientist
# 26             Data Engineer
# 29            Data Scientist
# 36              Data Analyst
# ...                      ...
# 785713        Cloud Engineer
# 785715          Data Analyst
# 785718      Business Analyst
# 785724         Data Engineer
# 785729         Data Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 21      Stage - data scientist – génération ia de donn...
# 26                                          Data Engineer
# 29                                         Data Scientist
# 36                                           Data Analyst
# ...                                                   ...
# 785713  Data Center Chief Engineer, AWS Infrastructure...
# 785715  Amul Careers 2023 - Apply Online - Data Analys...
# 785718                      Senior Performance QA Analyst
# 785724                 Junior Consultant Data Engineering
# 785729               Data Engineer Marketing Intelligence
#
#                       job_location  \
# 0                    Watertown, CT
# 21      Asnières-sur-Seine, France
# 26                   United States
# 29        Pune, Maharashtra, India
# 36                  Des Moines, IA
# ...                            ...
# 785713           Bangkok, Thailand
# 785715                       India
# 785718                       India
# 785724                Koln, Jerman
# 785729                      Jerman
#
#                                                   job_via job_schedule_type  \
# 0                                         via Work Nearby         Full-time
# 21                                           via Jobijoba         Full-time
# 26                                           via LinkedIn         Full-time
# 29                                             via Exusia         Full-time
# 36                                        via Trabajo.org         Full-time
# ...                                                   ...               ...
# 785713                                   melalui LinkedIn   Pekerjaan tetap
# 785715  melalui Jobsleworld - Jobs In India - Job Vaca...   Pekerjaan tetap
# 785718                                melalui BeBee India   Pekerjaan tetap
# 785724                          melalui BeBee Deutschland   Pekerjaan tetap
# 785729                          melalui BeBee Deutschland   Pekerjaan tetap
#
#         job_work_from_home          search_location     job_posted_date  \
# 0                    False     Texas, United States 2023-06-16 13:44:15
# 21                   False                   France 2023-02-23 13:41:21
# 26                   False                  Georgia 2023-09-15 13:56:18
# 29                   False                    India 2023-03-26 13:16:20
# 36                   False  Illinois, United States 2023-11-06 13:01:22
# ...                    ...                      ...                 ...
# 785713               False                 Thailand 2023-03-12 06:37:47
# 785715               False                    India 2023-03-13 06:16:28
# 785718               False                    India 2023-03-13 06:16:28
# 785724               False                  Germany 2023-03-13 06:19:07
# 785729               False                  Germany 2023-03-12 06:18:18
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 0                       False                 False  United States
# 21                      False                 False         France
# 26                       True                 False  United States
# 29                      False                 False          India
# 36                      False                  True  United States
# ...                       ...                   ...            ...
# 785713                  False                 False       Thailand
# 785715                  False                 False          India
# 785718                  False                 False          India
# 785724                  False                 False        Germany
# 785729                  False                 False        Germany
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 0             None              NaN              NaN
# 21            None              NaN              NaN
# 26            None              NaN              NaN
# 29            None              NaN              NaN
# 36            None              NaN              NaN
# ...            ...              ...              ...
# 785713        None              NaN              NaN
# 785715        None              NaN              NaN
# 785718        None              NaN              NaN
# 785724        None              NaN              NaN
# 785729        None              NaN              NaN
#
#                         company_name job_skills job_type_skills
# 0               Boehringer Ingelheim       None            None
# 21                   Credit Agricole       None            None
# 26       Infinite Computer Solutions       None            None
# 29                            Exusia       None            None
# 36                   Assuredpartners       None            None
# ...                              ...        ...             ...
# 785713     Amazon Web Services (AWS)       None            None
# 785715                          Amul       None            None
# 785718               Diebold Nixdorf       None            None
# 785724                  Target Reply       None            None
# 785729  IU Internationale Hochschule       None            None
#
# [117037 rows x 17 columns]

# %%
def clean_list(skill_list):
    if pd.notna(skill_list):
     return ast.literal_eval(skill_list)
df['job_skills'] = df['job_skills'].apply(clean_list)

# %%
type(df['job_skills'][1])
# Out:
# list

# %%
type(df['job_skills'][1])
# Out:
# list

# %% [markdown]
# CALCULATE PROJECTED SALARY FOR NEXT YEAR
#
# **.** SENIOR ROLE ASSUME 5%
#
#
# **.** OTHER ROLE ASUMME 3%

# %%
df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(lambda salary:salary *1.03)
df_salary[['salary_year_inflated', 'salary_year_avg'] ]
# Out:
#         salary_year_inflated  salary_year_avg
# 28             119653.606500      116168.5500
# 77             152981.780000      148526.0000
# 92             131127.240000      127308.0000
# 100            249384.341394      242120.7198
# 109             97252.703000       94420.1000
# ...                      ...              ...
# 785624         152125.082032      147694.2544
# 785641         163909.050000      159135.0000
# 785648         242448.803125      235387.1875
# 785682         172104.502500      167091.7500
# 785692         172104.502500      167091.7500
#
# [22003 rows x 2 columns]

# %%
def projected_salary(row):
    if senior in row['job_title_short']:
        return 1.05 * row['salary_year_avg']
    else:
        return 1.03 * roe['salary_year_avg']
    df_salary['salary_year_inflated'] = df_salary.apply(projected_salary , axis=1)

    df_salary[['job_title_short', 'salary_year_inflated', 'salary_year_avg'] ]

# %%
df_salary[['job_title_short', 'salary_year_inflated', 'salary_year_avg'] ]
# Out:
#        job_title_short  salary_year_inflated  salary_year_avg
# 28      Data Scientist         119653.606500      116168.5500
# 77       Data Engineer         152981.780000      148526.0000
# 92       Data Engineer         131127.240000      127308.0000
# 100     Data Scientist         249384.341394      242120.7198
# 109       Data Analyst          97252.703000       94420.1000
# ...                ...                   ...              ...
# 785624   Data Engineer         152125.082032      147694.2544
# 785641   Data Engineer         163909.050000      159135.0000
# 785648  Data Scientist         242448.803125      235387.1875
# 785682  Data Scientist         172104.502500      167091.7500
# 785692  Data Scientist         172104.502500      167091.7500
#
# [22003 rows x 3 columns]

# %%
import pandas as pd

data={
    'job_title_short':['Data Analyst', 'Data Scientist', 'Data Engineer'],
    'job_skills':[['excel', 'sql', 'python'],['python','r'],['aws','python','airflow']]
}

df_skills_lists = pd.DataFrame(data)

df_skills_lists
# Out:
#   job_title_short              job_skills
# 0    Data Analyst    [excel, sql, python]
# 1  Data Scientist             [python, r]
# 2   Data Engineer  [aws, python, airflow]

# %%
#for row in df_skills_lists.itertuples():
  #for skill in row.job_skills:
        #df_skills_lists[skill] = df_skills_lists['job_skills'].apply(lambda x: skill in x)
        #df_skills_lists[skill] = df_skills_lists[skill].astype(int)

#df_skills_lists.loc['Total'] = df_skills_lists.sum()  
#df_skills_lists

# %% [markdown]
# #THIS IS ALL NOT NEEDED INSTEAD WE CAN JUST USE EXPLOAD METHOD

# %%
df_skills_lists
# Out:
#   job_title_short              job_skills
# 0    Data Analyst    [excel, sql, python]
# 1  Data Scientist             [python, r]
# 2   Data Engineer  [aws, python, airflow]

# %%
df_skills_lists.explode('job_skills').value_counts('job_skills').plot(kind='bar')
# Out:
# <Axes: xlabel='job_skills'>

# %% [markdown]
# # Pandas : Expload()

# %%
#Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#Loading Data Sets
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data Cleanup
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df[['job_title_short', 'job_skills']].head(5)
# Out:
#         job_title_short                                         job_skills
# 0  Senior Data Engineer                                               None
# 1          Data Analyst         [r, python, sql, nosql, power bi, tableau]
# 2         Data Engineer  [python, sql, c#, azure, airflow, dax, docker,...
# 3         Data Engineer  [python, c++, java, matlab, aws, tensorflow, k...
# 4         Data Engineer  [bash, python, oracle, aws, ansible, puppet, j...

# %%
df_exploded= df.explode('job_skills')
df_exploded
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
# 785740                                 AWS System Analyst
#
#                                job_location              job_via  \
# 0                             Watertown, CT      via Work Nearby
# 1              Guadalajara, Jalisco, Mexico     via BeBee México
# 1              Guadalajara, Jalisco, Mexico     via BeBee México
# 1              Guadalajara, Jalisco, Mexico     via BeBee México
# 1              Guadalajara, Jalisco, Mexico     via BeBee México
# ...                                     ...                  ...
# 785739  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 785739  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 785739  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 785740                                India       melalui Trigyn
# 785740                                India       melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 1              Full-time               False                Mexico
# 1              Full-time               False                Mexico
# 1              Full-time               False                Mexico
# ...                  ...                 ...                   ...
# 785739   Pekerjaan tetap               False                 Sudan
# 785739   Pekerjaan tetap               False                 Sudan
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# ...                    ...                    ...                   ...
# 785739 2023-03-12 06:32:15                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785739          Sudan        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                       company_name  job_skills  \
# 0             Boehringer Ingelheim        None
# 1       Hewlett Packard Enterprise           r
# 1       Hewlett Packard Enterprise      python
# 1       Hewlett Packard Enterprise         sql
# 1       Hewlett Packard Enterprise       nosql
# ...                            ...         ...
# 785739                 Capital One       kafka
# 785739                 Capital One  kubernetes
# 785739                 Capital One      docker
# 785740                      Trigyn         aws
# 785740                      Trigyn        flow
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# ...                                                   ...
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [3777320 rows x 17 columns]

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1              [r, python, sql, nosql, power bi, tableau]
# 2       [python, sql, c#, azure, airflow, dax, docker,...
# 3       [python, c++, java, matlab, aws, tensorflow, k...
# 4       [bash, python, oracle, aws, ansible, puppet, j...
# ...                                                   ...
# 785736  [bash, python, perl, linux, unix, kubernetes, ...
# 785737                             [sas, sas, sql, excel]
# 785738                                [powerpoint, excel]
# 785739  [python, go, nosql, sql, mongo, shell, mysql, ...
# 785740                                        [aws, flow]
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %%
df_exploded['job_skills'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='job_skills'>

# %%
skill_count = df_exploded.groupby(['job_title_short', 'job_skills']).size()

type(skill_count)
# Out:
# pandas.core.series.Series

# %%
skill_count
# Out:
# job_title_short    job_skills
# Business Analyst   airflow        318
#                    airtable        17
#                    alteryx       1078
#                    angular         87
#                    ansible        120
#                                  ...
# Software Engineer  wrike            4
#                    wsl             13
#                    xamarin         35
#                    yarn           145
#                    zoom           229
# Length: 2256, dtype: int64

# %%
df_skill_count = skill_count.reset_index(name='skill_count')
df_skill_count = df_skill_count.sort_values(by='skill_count', ascending= False)

df_skill_count
# Out:
#             job_title_short   job_skills  skill_count
# 1066         Data Scientist       python       113711
# 865           Data Engineer          sql       113130
# 830           Data Engineer       python       108022
# 625            Data Analyst          sql        92428
# 1101         Data Scientist          sql        78982
# ...                     ...          ...          ...
# 266          Cloud Engineer       delphi            1
# 1920  Senior Data Scientist  objective-c            1
# 1400    Senior Data Analyst      couchdb            1
# 298          Cloud Engineer      haskell            1
# 631            Data Analyst         suse            1
#
# [2256 rows x 3 columns]

# %%
job_title='Data Engineer'
top_skills = 15

df_skill_final=df_skill_count[df_skill_count['job_title_short']==job_title].head(top_skills)

df_skill_final.plot(kind='barh', x='job_skills', y='skill_count')
plt.gca().invert_yaxis()
plt.title(f'Top{top_skills} skills for {job_title}s')
plt.xlabel('Job posting count')
plt.ylabel('')
plt.legend().set_visible(False)

# %% [markdown]
# # Matplotlib : Format Charts

# %%
#Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#Loading Data Sets
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data Cleanup
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
fig, ax = plt.subplots()

df['job_title_short'].value_counts().plot(kind='bar', ax=ax)
# Out:
# <Axes: xlabel='job_title_short'>

# %%
df['job_schedule_type'].value_counts().head(3)
# Out:
# job_schedule_type
# Full-time     701727
# Contractor     34793
# Internship      8742
# Name: count, dtype: int64

# %%
#Using pandas for ploting
fig, ax = plt.subplots(1, 2)

df['job_title_short'].value_counts().plot(kind='bar', ax=ax[0])
df['job_schedule_type'].value_counts().head(3).plot(kind='bar', ax=ax[1])

fig.tight_layout()

# %%
#Using Matplotlib for ploting

fig, ax= plt.subplots(1, 2)

ax[0].bar(df['job_title_short'].value_counts().index, df['job_title_short'].value_counts())
ax[1].bar(df['job_schedule_type'].value_counts().head(3).index, df['job_schedule_type'].value_counts().head(3))

plt.tight_layout()

# %% [markdown]
# # Matplotlib - Pie Plots

# %%
#Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#Loading Data Sets
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data Cleanup
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df['job_work_from_home'].value_counts().plot(kind='pie', startangle=90, autopct='%1.1f%%')
plt.title('Work From Home Status')
plt.ylabel("")
plt.show()

# %%
df[['job_work_from_home', 'job_no_degree_mention', 'job_health_insurance']]
# Out:
#         job_work_from_home  job_no_degree_mention  job_health_insurance
# 0                    False                  False                 False
# 1                    False                  False                 False
# 2                    False                  False                 False
# 3                    False                   True                 False
# 4                    False                  False                 False
# ...                    ...                    ...                   ...
# 785736               False                  False                 False
# 785737               False                  False                 False
# 785738               False                  False                 False
# 785739               False                  False                 False
# 785740               False                  False                 False
#
# [785741 rows x 3 columns]

# %%
fig, ax = plt.subplots(1, 3)

dict_column = {
    'job_work_from_home': 'Work from home',
    'job_no_degree_mention': 'Job Degree Reg.',
    'job_health_insurance': 'Health Insurance Offered'
}

for i, (column , title) in enumerate(dict_column.items()):
    ax[i].pie(df[column].value_counts(), startangle=90, autopct='%1.1f%%', labels=['False', 'True'])
    ax[i].set_title(title)

plt.show()

# %% [markdown]
# # Matplotlib : Scatter Plot

# %%
#Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#Loading Data Sets
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data Cleanup
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df= df[df['job_title_short'] == 'Data Analyst']

# %%
df_exploded = df.explode('job_skills')

skill_stats = df_exploded.groupby('job_skills').agg(
skill_count=('job_skills', 'count'),
median_salary=('salary_year_avg', 'median')
)

skill_stats= skill_stats.sort_values(by='skill_count', ascending=False).head(10)

# %%
skill_stats.plot(kind='scatter', x='skill_count', y='median_salary')
plt.xlabel('Count of job posting')
plt.ylabel('Median yearly salary ($USD)')
plt.title('Salary vs, Count of job Posting for Top 10 skills')
plt.tight_layout()

for i, txt in enumerate(skill_stats.index):
    plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], txt)
    
plt.show()
